# %%
import pandas as pd

data1 = pd.read_csv("../data/c1.csv")
records = data1.to_records(index=True)
data = [(int(i+1), float(record["lat"]), float(record["lon"]), record["name"], record["code"]) for i,record in enumerate(records)]
print(data)
# Out:
# [(1, 36.65, 117.0, '济南', '1_0'), (2, 36.29, 116.46, '平阴', '1_1'), (3, 36.97, 117.2, '济阳', '1_2'), (4, 37.31, 117.15, '商河', '1_3'), (5, 36.72, 117.53, '章丘', '1_4'), (6, 36.07, 120.33, '青岛', '2_0'), (7, 36.28, 120.0, '胶州', '2_1'), (8, 36.38, 120.45, '即墨', '2_2'), (9, 36.77, 119.97, '平度', '2_3'), (10, 35.88, 119.97, '胶南', '2_4'), (11, 36.86, 120.53, '莱西', '2_5'), (12, 36.8501, 119.6337, '平度铁投风电场中心', '2_12'), (13, 36.824031, 119.675549, '平度铁投风电场测风塔啊', '2_13'), (14, 36.0288786, 119.928, '白家华电', '2_14'), (15, 36.173611, 119.716667, '铺集华润', '2_15'), (16, 36.78, 118.05, '淄博', '3_0'), (17, 36.96, 118.1, '恒台', '3_1'), (18, 37.18, 117.66, '高青', '3_2'), (19, 36.18, 118.17, '沂源', '3_3'), (20, 34.86, 117.57, '枣庄', '4_0'), (21, 35.11, 117.17, '滕州', '4_1'), (22, 37.46, 118.49, '东营', '5_0'), (23, 37.59, 118.54, '垦利', '5_1'), (24, 37.49, 118.25, '利津', '5_2'), (25, 37.04, 118.41, '广饶', '5_3'), (26, 38.0198, 118.5063, '鱼光互补光伏', '5_4'), (27, 118.296476, 118.296476, '东营河口区东兴三力光伏电站', '5_5'), (28, 37.926389
# ...
